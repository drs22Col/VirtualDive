# %%
import requests
import pandas as pd
import numpy as np

class Records:
    """
    Returns a Records class instance with GBIF occurrence records stored
    in a pandas DataFrame for a queried taxon between a range of years.
    Parameters:
    -----------
    q: str
        Query taxonomic name.
    interval: tuple
        Range of years to return results for. Should be (min, max) tuple.
    Attributes:
    -----------
    baseurl: The REST API URL for GBIF.org.
    params: The parameter dictionary to filter GBIF search.
    df: Pandas DataFrame with returned records.
    sdf: A view of the 'df' DataFrame selecting only three relevant columns.
    """
    def __init__(self, q, interval, **kwargs):
        # the API url for searching GBIF occurrences
        self.baseurl = "http://api.gbif.org/v1/occurrence/search?"

        # the default REST API options plus user entered args
        self.params = {
            "q": q,
            'year': ",".join([str(i) for i in interval]),
            'basisOfRecord': "PRESERVED_SPECIMEN",
            'kingdom': "Animalia",
            'phylum': "Cnidaria",
            'order': "Scleractinia",
            'hasCoordinate': "true",
            'hasGeospatialIssue': "false",
            "offset": "0",
            "limit": "300",
        }

        # allow users to enter or modify other params using kwargs
        self.params.update(kwargs)

        # run the request query until all records are obtained
        self.df = pd.DataFrame(self._get_all_records())

    @property
    def sdf(self):
        """
        Return a copy of the current .df dataframe selecting only the three
        most generally relevant columns: species, year, and stateProvince.
        This is only meant for viewing and will raise a warning if you try to
        modify it since it is a copy, and thus you would be setting values on
        a selection of a selection. See pandas docs in the warning for detalis.
        """
        return self.df[["order", "species", "country", "stateProvince"]]

    def _get_all_records(self):
        "iterate until end of records"
        data = []
        while 1:
            # make request and store results
            res = requests.get(
                url=self.baseurl,
                params=self.params,
            )

            # check for errors
            res.raise_for_status()

            # increment counter
            self.params["offset"] = str(int(self.params["offset"]) + 300)

            # get data as json list of dicts and add to 'data' list
            idata = res.json()
            data += idata["results"]

            # stop when end of record is reached
            if idata["endOfRecords"]:
                break
        return data

# %%
rec = Records("Scleractinia", interval=(1990, 2017))

# %%
cleaning = rec.sdf
clean = cleaning[cleaning["species"].str.contains("NaN") == False]
cleanest = clean[clean["order"].str.contains("Scleractinia") == True]
cleanest
# Out:
#               order                    species        country  \
# 423    Scleractinia          Anomocora fecunda            NaN
# 474    Scleractinia          Madracis profunda            NaN
# 486    Scleractinia          Anomocora fecunda            NaN
# 564    Scleractinia          Anomocora fecunda            NaN
# 578    Scleractinia          Anomocora fecunda            NaN
# 642    Scleractinia           Flabellum chunii            NaN
# 661    Scleractinia           Acropora pulchra      Australia
# 662    Scleractinia           Acropora pulchra      Australia
# 663    Scleractinia        Acropora hyacinthus      Australia
# 667    Scleractinia           Acropora pulchra      Australia
# 668    Scleractinia           Acropora pulchra      Australia
# 669    Scleractinia        Acropora hyacinthus      Australia
# 671    Scleractinia           Acropora pulchra      Australia
# 672    Scleractinia           Acropora pulchra      Australia
# 673    Scleractinia        Acropora hyacinthus      Australia
# 675    Scleractinia           Acropora pulchra      Australia
# 677    Scleractinia           Acropora pulchra      Australia
# 678    Scleractinia           Acropora pulchra      Australia
# 679    Scleractinia          Acropora cytherea      Australia
# 680    Scleractinia           Acropora pulchra      Australia
# 681    Scleractinia          Acropora cytherea      Australia
# 686    Scleractinia        Acropora hyacinthus      Australia
# 689    Scleractinia    Caryophyllia alaskensis  United States
# 690    Scleractinia           Acropora pulchra      Australia
# 691    Scleractinia          Acropora cytherea      Australia
# 692    Scleractinia           Acropora pulchra      Australia
# 693    Scleractinia           Acropora pulchra      Australia
# 694    Scleractinia           Acropora pulchra      Australia
# 696    Scleractinia           Acropora pulchra      Australia
# 697    Scleractinia          Acropora cytherea      Australia
# ...             ...                        ...            ...
# 39912  Scleractinia         Madracis myriaster       Colombia
# 39913  Scleractinia     Pocillopora damicornis       Colombia
# 39914  Scleractinia     Pocillopora damicornis       Colombia
# 39915  Scleractinia            Porites porites       Colombia
# 39916  Scleractinia         Porites astreoides       Colombia
# 39917  Scleractinia        Agaricia tenuifolia       Colombia
# 39918  Scleractinia        Eusmilia fastigiata       Colombia
# 39919  Scleractinia     Pocillopora damicornis       Colombia
# 39920  Scleractinia             Porites lobata       Colombia
# 39921  Scleractinia          Madracis decactis       Colombia
# 39922  Scleractinia        Agaricia agaricites       Colombia
# 39923  Scleractinia     Pocillopora damicornis       Colombia
# 39924  Scleractinia       Meandrina meandrites       Colombia
# 39925  Scleractinia            Oculina diffusa       Colombia
# 39926  Scleractinia    Pseudodiploria strigosa       Colombia
# 39927  Scleractinia  Stephanocoenia intersepta       Colombia
# 39928  Scleractinia        Pocillopora grandis       Colombia
# 39929  Scleractinia     Pocillopora damicornis       Colombia
# 39930  Scleractinia       Pocillopora capitata       Colombia
# 39931  Scleractinia         Porites astreoides       Colombia
# 39932  Scleractinia              Pavona clavus       Colombia
# 39933  Scleractinia        Colpophyllia natans       Colombia
# 39934  Scleractinia     Pocillopora damicornis       Colombia
# 39935  Scleractinia        Siderastrea radians       Colombia
# 39936  Scleractinia       Acropora cervicornis       Colombia
# 39937  Scleractinia        Pocillopora elegans       Colombia
# 39938  Scleractinia     Pocillopora damicornis       Colombia
# 39939  Scleractinia              Pavona clavus       Colombia
# 39940  Scleractinia     Pocillopora damicornis       Colombia
# 39941  Scleractinia     Pocillopora damicornis       Colombia
#
#                                            stateProvince
# 423                                                  NaN
# 474                                                  NaN
# 486                                                  NaN
# 564                                                  NaN
# 578                                                  NaN
# 642                                                  NaN
# 661                                                  NaN
# 662                                                  NaN
# 663                                                  NaN
# 667                                                  NaN
# 668                                                  NaN
# 669                                                  NaN
# 671                                                  NaN
# 672                                                  NaN
# 673                                                  NaN
# 675                                                  NaN
# 677                                                  NaN
# 678                                                  NaN
# 679                                                  NaN
# 680                                                  NaN
# 681                                                  NaN
# 686                                                  NaN
# 689                                               Alaska
# 690                                                  NaN
# 691                                                  NaN
# 692                                                  NaN
# 693                                                  NaN
# 694                                                  NaN
# 696                                                  NaN
# 697                                                  NaN
# ...                                                  ...
# 39912                                          Magdalena
# 39913                                              Cauca
# 39914                                              Cauca
# 39915                                          Magdalena
# 39916  Archipiélago de San Andrés, Providencia y Sant...
# 39917                                            Córdoba
# 39918                                          Magdalena
# 39919                                              Cauca
# 39920                                              Cauca
# 39921                                            Córdoba
# 39922                                         La Guajira
# 39923                                              Cauca
# 39924                                          Magdalena
# 39925                                         La Guajira
# 39926  Archipiélago de San Andrés, Providencia y Sant...
# 39927                                          Magdalena
# 39928                                              Cauca
# 39929                                              Cauca
# 39930                                              Cauca
# 39931                                            Córdoba
# 39932                                              Cauca
# 39933                                          Magdalena
# 39934                                              Cauca
# 39935                                          Magdalena
# 39936                                          Magdalena
# 39937                                              Cauca
# 39938                                              Cauca
# 39939                                              Cauca
# 39940                                              Cauca
# 39941                                              Cauca
#
# [32093 rows x 4 columns]

# %%
len(clean.index)
# Out:
# 5819

# %%
rec.sdf
# Out:
#                 family                   species  year        country  \
# 0                  NaN                       NaN  1967  United States
# 1                  NaN                       NaN  1965  United States
# 2                  NaN                       NaN  2012  United States
# 3                  NaN                       NaN  1988  United States
# 4                  NaN                       NaN  1978  United States
# 5                  NaN                       NaN  2011  United States
# 6                  NaN                       NaN  1978  United States
# 7                  NaN                       NaN  1988  United States
# 8                  NaN                       NaN  1978  United States
# 9                  NaN                       NaN  2005  United States
# 10                 NaN                       NaN  2010  United States
# 11                 NaN                       NaN  2011  United States
# 12                 NaN                       NaN  1965  United States
# 13                 NaN                       NaN  1978  United States
# 14                 NaN                       NaN  2009  United States
# 15                 NaN                       NaN  2010  United States
# 16                 NaN                       NaN  1965  United States
# 17                 NaN                       NaN  1988  United States
# 18                 NaN                       NaN  2011  United States
# 19                 NaN                       NaN  1972  United States
# 20                 NaN                       NaN  1977  United States
# 21                 NaN                       NaN  2011  United States
# 22                 NaN                       NaN  1967  United States
# 23                 NaN                       NaN  2012  United States
# 24                 NaN                       NaN  2010  United States
# 25                 NaN                       NaN  2011  United States
# 26                 NaN                       NaN  2011  United States
# 27                 NaN                       NaN  1971  United States
# 28                 NaN                       NaN  1977  United States
# 29                 NaN                       NaN  1989  United States
# ...                ...                       ...   ...            ...
# 6342  Dendrophylliidae         Turbinaria ornata  2000  United States

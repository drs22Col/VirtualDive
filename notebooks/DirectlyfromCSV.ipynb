# %%
import pandas as pd
import numpy as np
import os
datadir = os.path.abspath('..')+"/data/GBIFData.csv"
gbifdata=pd.read_csv(datadir)
# Out:
# /home/nickpichome/miniconda3/envs/py36/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (17,18) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
gbifdata.head(10)
# Out:
#            family        genus              species taxonrank countrycode  \
# 0        Mussidae        Favia         Favia fragum   SPECIES       1795)
# 1  Siderastreidae  Siderastrea  Siderastrea siderea   SPECIES       1768)
# 2       Poritidae      Porites      Porites porites   SPECIES       1766)
# 3        Mussidae        Favia         Favia fragum   SPECIES       1795)
# 4     Acroporidae     Acropora     Acropora palmata   SPECIES       1816)
# 5  Siderastreidae  Siderastrea  Siderastrea radians   SPECIES       1766)
# 6  Siderastreidae  Siderastrea  Siderastrea siderea   SPECIES       1768)
# 7  Siderastreidae  Siderastrea  Siderastrea siderea   SPECIES       1768)
# 8  Siderastreidae  Siderastrea  Siderastrea siderea   SPECIES       1768)
# 9  Siderastreidae  Siderastrea  Siderastrea siderea   SPECIES       1768)
#
#   locality taxonkey Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10 Unnamed: 11  \
# ...
